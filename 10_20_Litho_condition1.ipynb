# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #라벨링 전처리 part

# %%
# 라벨링 데이터 생성시 컨디션과 모드 선택
condition = 3
mode = 2

# %%
if (condition==1):
    raw_data = pd.read_csv('/content/drive/My Drive/datasets/LithoAI/BABCdata_condition_1.csv')
elif (condition==2):
    print("아직 준비되지 않았습니다.")
elif (condition==3):
    raw_data = pd.read_csv('/content/drive/My Drive/datasets/LithoAI/BABCdata_condition_3.csv')
else:
    print("올바른 condition이 아닙니다.")

# %%
test_data = pd.read_csv('/content/drive/My Drive/datasets/LithoAI/BABCdata_condition_1.csv')

# %%
test_data.head()
# Out:
#    Unnamed: 0     TE_r          TE_t     TM_r  ...      n1     k1      d1  anlge
# 0           0  69.8447  9.699340e-77  67.5426  ...  0.8808  2.778  1000.0   20.0
# 1           1  61.7972  1.210240e-76  59.8416  ...  0.8808  2.778  1000.0   20.0
# 2           2  48.8629  1.580240e-76  48.3188  ...  0.8808  2.778  1000.0   20.0
# 3           3  35.0265  1.944880e-76  37.0732  ...  0.8808  2.778  1000.0   20.0
# 4           4  32.2103  1.961420e-76  35.0591  ...  0.8808  2.778  1000.0   20.0
#
# [5 rows x 18 columns]

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1771561 entries, 0 to 1771560
# Data columns (total 18 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   TE_r        float64
#  2   TE_t        float64
#  3   TM_r        float64
#  4   TM_t        float64
#  5   layer3      float64
#  6   n3          float64
#  7   k3          float64
#  8   d3          float64
#  9   layer2      float64
#  10  n2          float64
#  11  k2          float64
#  12  d2          float64
#  13  layer1      float64
#  14  n1          float64
#  15  k1          float64
#  16  d1          float64
#  17  anlge       float64
# dtypes: float64(17), int64(1)
# memory usage: 243.3 MB

# %%
if (mode == 1):
    x_i = raw_data['TE_r'].values
    label = list(map(int,x_i))

    raw_data['label'] = label
elif (mode == 2):
    x_i = raw_data['TM_r'].values
    label = list(map(int,x_i))

    raw_data['label'] = label

# %%
if (condition == 1):
    if (mode == 1):
        raw_data.to_csv('/content/drive/My Drive/datasets/LithoAI/20201020_condition1_TE_labeling.csv', mode='a')
    elif (mode == 2):
        raw_data.to_csv('/content/drive/My Drive/datasets/LithoAI/20201020_condition1_TM_labeling.csv', mode='a')
elif (condition == 3):
    if (mode == 1):
        raw_data.to_csv('/content/drive/My Drive/datasets/LithoAI/20201020_condition3_TE_labeling.csv', mode='a')
    elif (mode == 2):
        raw_data.to_csv('/content/drive/My Drive/datasets/LithoAI/20201020_condition3_TM_labeling.csv', mode='a')

# %% [markdown]
# #라이브러리 불러오기

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
#from bayes_opt import BayesianOptimization

import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import seaborn as sns
import numpy as np
import cv2

# %% [markdown]
# #입력 데이터 설정

# %%
# 위의 라벨링 데이터와는 별개의 mode 설정

condition = 1
mode = 1 #  TE: mode =1  , TM: mode=2

if (condition==1):
    if (mode == 1):
        input_data = pd.read_csv('/content/drive/My Drive/datasets/LithoAI/20201020_condition1_TE_labeling.csv')
    elif (mode == 2):
        input_data = pd.read_csv('/content/drive/My Drive/datasets/LithoAI/20201020_condition1_TM_labeling.csv')
elif (condition==3):
    if (mode == 1):
        input_data = pd.read_csv('/content/drive/My Drive/datasets/LithoAI/20201020_condition3_TE_labeling.csv')
    elif (mode == 2):
        input_data = pd.read_csv('/content/drive/My Drive/datasets/LithoAI/20201020_condition3_TM_labeling.csv')

# %%
input_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     TE_r          TE_t  ...     k1      d1  anlge  label
# 0           0             0  69.8447  9.699340e-77  ...  2.778  1000.0   20.0     69
# 1           1             1  61.7972  1.210240e-76  ...  2.778  1000.0   20.0     61
# 2           2             2  48.8629  1.580240e-76  ...  2.778  1000.0   20.0     48
# 3           3             3  35.0265  1.944880e-76  ...  2.778  1000.0   20.0     35
# 4           4             4  32.2103  1.961420e-76  ...  2.778  1000.0   20.0     32
#
# [5 rows x 20 columns]

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1771561 entries, 0 to 1771560
# Data columns (total 20 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    int64
#  1   Unnamed: 0.1  int64
#  2   TE_r          float64
#  3   TE_t          float64
#  4   TM_r          float64
#  5   TM_t          float64
#  6   layer3        float64
#  7   n3            float64
#  8   k3            float64
#  9   d3            float64
#  10  layer2        float64
#  11  n2            float64
#  12  k2            float64
#  13  d2            float64
#  14  layer1        float64
#  15  n1            float64
#  16  k1            float64
#  17  d1            float64
#  18  anlge         float64
#  19  label         int64
# dtypes: float64(17), int64(3)
# memory usage: 270.3 MB

# %%
input_data.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  ...      anlge         label
# count  1.771561e+06  1.771561e+06  ...  1771561.0  1.771561e+06
# mean   8.857800e+05  8.857800e+05  ...       20.0  5.109947e+01
# std    5.114058e+05  5.114058e+05  ...        0.0  1.456691e+01
# min    0.000000e+00  0.000000e+00  ...       20.0  1.900000e+01
# 25%    4.428900e+05  4.428900e+05  ...       20.0  3.800000e+01
# 50%    8.857800e+05  8.857800e+05  ...       20.0  5.400000e+01
# 75%    1.328670e+06  1.328670e+06  ...       20.0  6.400000e+01
# max    1.771560e+06  1.771560e+06  ...       20.0  7.100000e+01
#
# [8 rows x 20 columns]

# %% [markdown]
# #라벨링 설정및 불필요 변수 제거

# %%
X_data = input_data.copy()

# %% [markdown]
# 데이터 경량화(선택)

# %%
# 전체적인 데이터량을 줄여버리는데 그중에 라벨링의 값이 40이 넘는 부분을 버린다.
X_data = X_data[X_data.label < 40]

# %%
y = X_data['label']

# %%
X_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     TE_r          TE_t  ...     k1      d1  anlge  label
# 0           0             0  69.8447  9.699340e-77  ...  2.778  1000.0   20.0     69
# 1           1             1  61.7972  1.210240e-76  ...  2.778  1000.0   20.0     61
# 2           2             2  48.8629  1.580240e-76  ...  2.778  1000.0   20.0     48
# 3           3             3  35.0265  1.944880e-76  ...  2.778  1000.0   20.0     35
# 4           4             4  32.2103  1.961420e-76  ...  2.778  1000.0   20.0     32
#
# [5 rows x 20 columns]

# %%
X_data.drop('TE_t', axis=1, inplace=True)

# %%
X_data.drop('TM_t', axis=1, inplace=True)

# %%
X_data.drop('TE_r', axis=1, inplace=True)

# %%
X_data.drop('TM_r', axis=1, inplace=True)

# %%
X_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
X_data.drop('Unnamed: 0.1', axis=1, inplace=True)

# %%
X_data.drop('label', axis=1, inplace=True)

# %%
X_data.drop('layer1', axis=1, inplace=True)

# %%
X_data.drop('layer2', axis=1, inplace=True)

# %%
X_data.drop('layer3', axis=1, inplace=True)

# %%
X_data.head()
# Out:
#     n3     k3   d3   n2     k2    d2      n1     k1      d1  anlge
# 0  1.7  0.015  0.0  1.8  0.016   0.0  0.8808  2.778  1000.0   20.0
# 1  1.7  0.015  0.0  1.8  0.016   5.0  0.8808  2.778  1000.0   20.0
# 2  1.7  0.015  0.0  1.8  0.016  10.0  0.8808  2.778  1000.0   20.0
# 3  1.7  0.015  0.0  1.8  0.016  15.0  0.8808  2.778  1000.0   20.0
# 4  1.7  0.015  0.0  1.8  0.016  20.0  0.8808  2.778  1000.0   20.0

# %% [markdown]
# #고정변수 제거 (선택?)

# %%
X_data.drop('anlge', axis=1 , inplace=True)

# %%
X_data.drop('n1', axis=1, inplace=True)

# %%
X_data.drop('k1', axis=1, inplace=True)

# %%
X_data.drop('d1', axis=1, inplace=True)

# %%
X_data.head()
# Out:
#     n3     k3   d3   n2     k2    d2
# 0  1.7  0.015  0.0  1.8  0.016   0.0
# 1  1.7  0.015  0.0  1.8  0.016   5.0
# 2  1.7  0.015  0.0  1.8  0.016  10.0
# 3  1.7  0.015  0.0  1.8  0.016  15.0
# 4  1.7  0.015  0.0  1.8  0.016  20.0

# %% [markdown]
# # Train Test dataset 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y, random_state=1234)

# %% [markdown]
# # Labeling 분포 확인

# %%
y.value_counts().sort_index()
# Out:
# 19        51
# 20       564
# 21      3192
# 22      9505
# 23     18435
# 24     25871
# 25     29511
# 26     28839
# 27     25372
# 28     22737
# 29     30000
# 30     39689
# 31     32370
# 32     23281
# 33     22074
# 34     24325
# 35     25050
# 36     27038
# 37     31770
# 38     36627
# 39     37540
# 40     35693
# 41     28761
# 42     19681
# 43     12548
# 44     11539
# 45     10537
# 46     11691
# 47     18923
# 48     30009
# 49     35481
# 50     37862
# 51     40750
# 52     42077
# 53     39405
# 54     33055
# 55     23245
# 56     17093
# 57     18826
# 58     26372
# 59     36752
# 60     54749
# 61     69268
# 62     74636
# 63     61641
# 64     56460
# 65     66392
# 66     93618
# 67    102055
# 68     85699
# 69     62254
# 70     19050
# 71      1598
# Name: label, dtype: int64

# %%
lab = y.values

# %%
plt.figure()
plt.hist(lab)
plt.title('label_distribution')
plt.xlabel('TM_reflection')
plt.ylabel('count')
#plt.show()
plt.savefig('/content/drive/My Drive/datasets/LithoAI/Condition3_TM.png')

# %% [markdown]
# # XGBClassfier 모델 생성

# %%
bst = xgb.XGBClassifier(random_state=1234)

# %% [markdown]
# # XGBClassifier 모델의 학습

# %%
# subsample 0.8이랑 0.6 차이 확인해보기
bst = xgb.XGBClassifier(n_estimators=281, learning_rate=0.2, max_depth=9, subsample=0.6, random_state=1234)

# %%
evals = [(X_test,y_test)]
bst.fit(X_train, y_train, early_stopping_rounds=10, eval_metric = ["mlogloss","merror"], eval_set=evals, verbose=1)
# Out:
# [0]	validation_0-mlogloss:2.76704	validation_0-merror:0.596917
# Multiple eval metrics have been passed: 'validation_0-merror' will be used for early stopping.
#
# Will train until validation_0-merror hasn't improved in 10 rounds.
# [1]	validation_0-mlogloss:2.44101	validation_0-merror:0.541047
# [2]	validation_0-mlogloss:2.23625	validation_0-merror:0.510302
# [3]	validation_0-mlogloss:2.07585	validation_0-merror:0.485514
# [4]	validation_0-mlogloss:1.95024	validation_0-merror:0.466657
# [5]	validation_0-mlogloss:1.83904	validation_0-merror:0.447519
# [6]	validation_0-mlogloss:1.74451	validation_0-merror:0.430524
# [7]	validation_0-mlogloss:1.65613	validation_0-merror:0.414698
# [8]	validation_0-mlogloss:1.58227	validation_0-merror:0.400984
# [9]	validation_0-mlogloss:1.5161	validation_0-merror:0.387452
# [10]	validation_0-mlogloss:1.45499	validation_0-merror:0.375284
# [11]	validation_0-mlogloss:1.40252	validation_0-merror:0.365858
# [12]	validation_0-mlogloss:1.35112	validation_0-merror:0.354439
# [13]	validation_0-mlogloss:1.3047	validation_0-merror:0.34494
# [14]	validation_0-mlogloss:1.26051	validation_0-merror:0.335566
# [15]	validation_0-mlogloss:1.2198	validation_0-merror:0.326376
# [16]	validation_0-mlogloss:1.1834	validation_0-merror:0.317992
# [17]	validation_0-mlogloss:1.15025	validation_0-merror:0.310383
# [18]	validation_0-mlogloss:1.11728	validation_0-merror:0.301413
# [19]	validation_0-mlogloss:1.08736	validation_0-merror:0.293867
# [20]	validation_0-mlogloss:1.05887	validation_0-merror:0.287789
# [21]	validation_0-mlogloss:1.03207	validation_0-merror:0.28034
# [22]	validation_0-mlogloss:1.00595	validation_0-merror:0.273889
# [23]	validation_0-mlogloss:0.98101	validation_0-merror:0.267267
# [24]	validation_0-mlogloss:0.958506	validation_0-merror:0.261498
# [25]	validation_0-mlogloss:0.936139	validation_0-merror:0.255609
# [26]	validation_0-mlogloss:0.913815	validation_0-merror:0.249779
# [27]	validation_0-mlogloss:0.893438	validation_0-merror:0.243855
# [28]	validation_0-mlogloss:0.873221	validation_0-merror:0.238686
# [29]	validation_0-mlogloss:0.854336	validation_0-merror:0.233423
# [30]	validation_0-mlogloss:0.835356	validation_0-merror:0.228282
# [31]	validation_0-mlogloss:0.819429	validation_0-merror:0.224191
# [32]	validation_0-mlogloss:0.803622	validation_0-merror:0.220165
# [33]	validation_0-mlogloss:0.788833	validation_0-merror:0.216055
# [34]	validation_0-mlogloss:0.773696	validation_0-merror:0.212
# [35]	validation_0-mlogloss:0.760624	validation_0-merror:0.20893
# [36]	validation_0-mlogloss:0.746345	validation_0-merror:0.205014
# [37]	validation_0-mlogloss:0.73223	validation_0-merror:0.201228
# [38]	validation_0-mlogloss:0.71857	validation_0-merror:0.197909
# [39]	validation_0-mlogloss:0.705901	validation_0-merror:0.194102
# [40]	validation_0-mlogloss:0.693686	validation_0-merror:0.190853
# [41]	validation_0-mlogloss:0.682099	validation_0-merror:0.187658
# [42]	validation_0-mlogloss:0.671218	validation_0-merror:0.184619
# [43]	validation_0-mlogloss:0.660556	validation_0-merror:0.181643
# [44]	validation_0-mlogloss:0.650623	validation_0-merror:0.17911
# [45]	validation_0-mlogloss:0.640685	validation_0-merror:0.176073
# [46]	validation_0-mlogloss:0.630776	validation_0-merror:0.173119
# [47]	validation_0-mlogloss:0.621198	validation_0-merror:0.170092
# [48]	validation_0-mlogloss:0.611613	validation_0-merror:0.167163
# [49]	validation_0-mlogloss:0.602438	validation_0-merror:0.164684
# [50]	validation_0-mlogloss:0.594228	validation_0-merror:0.162318
# [51]	validation_0-mlogloss:0.586223	validation_0-merror:0.159917
# [52]	validation_0-mlogloss:0.578716	validation_0-merror:0.158163
# [53]	validation_0-mlogloss:0.571076	validation_0-merror:0.1564
# [54]	validation_0-mlogloss:0.563584	validation_0-merror:0.154056
# [55]	validation_0-mlogloss:0.556191	validation_0-merror:0.151875
# [56]	validation_0-mlogloss:0.549138	validation_0-merror:0.149897
# [57]	validation_0-mlogloss:0.541826	validation_0-merror:0.148115
# [58]	validation_0-mlogloss:0.534708	validation_0-merror:0.146359
# [59]	validation_0-mlogloss:0.527922	validation_0-merror:0.144442
# [60]	validation_0-mlogloss:0.521344	validation_0-merror:0.142622
# [61]	validation_0-mlogloss:0.515175	validation_0-merror:0.140904
# [62]	validation_0-mlogloss:0.509178	validation_0-merror:0.139224
# [63]	validation_0-mlogloss:0.502873	validation_0-merror:0.137605
# [64]	validation_0-mlogloss:0.497038	validation_0-merror:0.135828
# [65]	validation_0-mlogloss:0.491525	validation_0-merror:0.134297
# [66]	validation_0-mlogloss:0.485529	validation_0-merror:0.132773
# [67]	validation_0-mlogloss:0.479472	validation_0-merror:0.131089
# [68]	validation_0-mlogloss:0.474058	validation_0-merror:0.129411
# [69]	validation_0-mlogloss:0.468645	validation_0-merror:0.127709
# [70]	validation_0-mlogloss:0.462942	validation_0-merror:0.125868
# [71]	validation_0-mlogloss:0.458023	validation_0-merror:0.124794
# [72]	validation_0-mlogloss:0.452838	validation_0-merror:0.123186
# [73]	validation_0-mlogloss:0.447862	validation_0-merror:0.121825
# [74]	validation_0-mlogloss:0.443461	validation_0-merror:0.12031
# [75]	validation_0-mlogloss:0.438845	validation_0-merror:0.119009
# [76]	validation_0-mlogloss:0.434476	validation_0-merror:0.117889
# [77]	validation_0-mlogloss:0.430259	validation_0-merror:0.116866
# [78]	validation_0-mlogloss:0.426033	validation_0-merror:0.115645
# [79]	validation_0-mlogloss:0.421937	validation_0-merror:0.114615
# [80]	validation_0-mlogloss:0.417746	validation_0-merror:0.113423
# [81]	validation_0-mlogloss:0.413725	validation_0-merror:0.112387
# [82]	validation_0-mlogloss:0.410021	validation_0-merror:0.111398
# [83]	validation_0-mlogloss:0.406435	validation_0-merror:0.110296
# [84]	validation_0-mlogloss:0.402858	validation_0-merror:0.109399
# [85]	validation_0-mlogloss:0.399215	validation_0-merror:0.108634
# [86]	validation_0-mlogloss:0.395457	validation_0-merror:0.107704
# [87]	validation_0-mlogloss:0.391939	validation_0-merror:0.106776
# [88]	validation_0-mlogloss:0.388504	validation_0-merror:0.105956
# [89]	validation_0-mlogloss:0.385407	validation_0-merror:0.105073
# [90]	validation_0-mlogloss:0.381804	validation_0-merror:0.104265
# [91]	validation_0-mlogloss:0.378761	validation_0-merror:0.103398
# [92]	validation_0-mlogloss:0.375537	validation_0-merror:0.102711
# [93]	validation_0-mlogloss:0.372645	validation_0-merror:0.10212
# [94]	validation_0-mlogloss:0.369636	validation_0-merror:0.101273
# [95]	validation_0-mlogloss:0.366842	validation_0-merror:0.100749
# [96]	validation_0-mlogloss:0.364194	validation_0-merror:0.099937
# [97]	validation_0-mlogloss:0.361496	validation_0-merror:0.09928
# [98]	validation_0-mlogloss:0.358883	validation_0-merror:0.098841
# [99]	validation_0-mlogloss:0.356295	validation_0-merror:0.097995
# [100]	validation_0-mlogloss:0.353758	validation_0-merror:0.097351
# [101]	validation_0-mlogloss:0.35101	validation_0-merror:0.096703
# [102]	validation_0-mlogloss:0.348293	validation_0-merror:0.095949
# [103]	validation_0-mlogloss:0.345687	validation_0-merror:0.095428
# [104]	validation_0-mlogloss:0.343443	validation_0-merror:0.094764
# [105]	validation_0-mlogloss:0.341034	validation_0-merror:0.094355
# [106]	validation_0-mlogloss:0.33879	validation_0-merror:0.093845
# [107]	validation_0-mlogloss:0.336323	validation_0-merror:0.093355
# [108]	validation_0-mlogloss:0.334035	validation_0-merror:0.092765
# [109]	validation_0-mlogloss:0.331829	validation_0-merror:0.092025
# [110]	validation_0-mlogloss:0.329903	validation_0-merror:0.091451
# [111]	validation_0-mlogloss:0.327825	validation_0-merror:0.091122
# [112]	validation_0-mlogloss:0.3257	validation_0-merror:0.090654
# [113]	validation_0-mlogloss:0.323419	validation_0-merror:0.090162
# [114]	validation_0-mlogloss:0.32151	validation_0-merror:0.089862
# [115]	validation_0-mlogloss:0.319529	validation_0-merror:0.089327
# [116]	validation_0-mlogloss:0.317572	validation_0-merror:0.088986
# [117]	validation_0-mlogloss:0.315519	validation_0-merror:0.08841
# [118]	validation_0-mlogloss:0.313767	validation_0-merror:0.088062
# [119]	validation_0-mlogloss:0.3119	validation_0-merror:0.087529
# [120]	validation_0-mlogloss:0.3102	validation_0-merror:0.087139
# [121]	validation_0-mlogloss:0.308451	validation_0-merror:0.086748
# [122]	validation_0-mlogloss:0.306569	validation_0-merror:0.086337
# [123]	validation_0-mlogloss:0.304841	validation_0-merror:0.086021
# [124]	validation_0-mlogloss:0.303222	validation_0-merror:0.085608
# [125]	validation_0-mlogloss:0.301515	validation_0-merror:0.085247
# [126]	validation_0-mlogloss:0.299965	validation_0-merror:0.084773
# [127]	validation_0-mlogloss:0.298346	validation_0-merror:0.084596
# [128]	validation_0-mlogloss:0.296674	validation_0-merror:0.084185
# [129]	validation_0-mlogloss:0.295063	validation_0-merror:0.083829
# [130]	validation_0-mlogloss:0.293523	validation_0-merror:0.083393
# [131]	validation_0-mlogloss:0.291987	validation_0-merror:0.083194
# [132]	validation_0-mlogloss:0.290496	validation_0-merror:0.082989
# [133]	validation_0-mlogloss:0.288952	validation_0-merror:0.082528
# [134]	validation_0-mlogloss:0.287406	validation_0-merror:0.082239
# [135]	validation_0-mlogloss:0.286004	validation_0-merror:0.081887
# [136]	validation_0-mlogloss:0.284644	validation_0-merror:0.081677
# [137]	validation_0-mlogloss:0.283241	validation_0-merror:0.081395
# [138]	validation_0-mlogloss:0.281828	validation_0-merror:0.080975
# [139]	validation_0-mlogloss:0.280506	validation_0-merror:0.080589
# [140]	validation_0-mlogloss:0.279222	validation_0-merror:0.080469
# [141]	validation_0-mlogloss:0.277768	validation_0-merror:0.08013
# [142]	validation_0-mlogloss:0.276544	validation_0-merror:0.080011
# [143]	validation_0-mlogloss:0.275294	validation_0-merror:0.079816
# [144]	validation_0-mlogloss:0.273975	validation_0-merror:0.079482
# [145]	validation_0-mlogloss:0.272723	validation_0-merror:0.079327
# [146]	validation_0-mlogloss:0.271478	validation_0-merror:0.079024
# [147]	validation_0-mlogloss:0.270299	validation_0-merror:0.078733
# [148]	validation_0-mlogloss:0.269115	validation_0-merror:0.078525
# [149]	validation_0-mlogloss:0.26789	validation_0-merror:0.078313
# [150]	validation_0-mlogloss:0.266773	validation_0-merror:0.078055
# [151]	validation_0-mlogloss:0.265547	validation_0-merror:0.077778
# [152]	validation_0-mlogloss:0.264366	validation_0-merror:0.07759
# [153]	validation_0-mlogloss:0.263383	validation_0-merror:0.077328
# [154]	validation_0-mlogloss:0.262321	validation_0-merror:0.077089
# [155]	validation_0-mlogloss:0.261124	validation_0-merror:0.077021
# [156]	validation_0-mlogloss:0.260033	validation_0-merror:0.076908
# [157]	validation_0-mlogloss:0.259022	validation_0-merror:0.076829
# [158]	validation_0-mlogloss:0.257997	validation_0-merror:0.076597
# [159]	validation_0-mlogloss:0.256981	validation_0-merror:0.076335
# [160]	validation_0-mlogloss:0.255988	validation_0-merror:0.076109
# [161]	validation_0-mlogloss:0.255025	validation_0-merror:0.075949
# [162]	validation_0-mlogloss:0.254026	validation_0-merror:0.075825
# [163]	validation_0-mlogloss:0.253073	validation_0-merror:0.075782
# [164]	validation_0-mlogloss:0.25213	validation_0-merror:0.075481
# [165]	validation_0-mlogloss:0.251152	validation_0-merror:0.075294
# [166]	validation_0-mlogloss:0.250261	validation_0-merror:0.075228
# [167]	validation_0-mlogloss:0.249246	validation_0-merror:0.074996
# [168]	validation_0-mlogloss:0.248293	validation_0-merror:0.074788
# [169]	validation_0-mlogloss:0.247378	validation_0-merror:0.074639
# [170]	validation_0-mlogloss:0.246602	validation_0-merror:0.074492
# [171]	validation_0-mlogloss:0.245686	validation_0-merror:0.074377
# [172]	validation_0-mlogloss:0.244848	validation_0-merror:0.074294
# [173]	validation_0-mlogloss:0.244079	validation_0-merror:0.07421
# [174]	validation_0-mlogloss:0.243247	validation_0-merror:0.07396
# [175]	validation_0-mlogloss:0.242423	validation_0-merror:0.07382
# [176]	validation_0-mlogloss:0.241625	validation_0-merror:0.073698
# [177]	validation_0-mlogloss:0.240798	validation_0-merror:0.073702
# [178]	validation_0-mlogloss:0.239974	validation_0-merror:0.073506
# [179]	validation_0-mlogloss:0.239201	validation_0-merror:0.073474
# [180]	validation_0-mlogloss:0.238381	validation_0-merror:0.073251
# [181]	validation_0-mlogloss:0.23751	validation_0-merror:0.073183
# [182]	validation_0-mlogloss:0.236801	validation_0-merror:0.073086
# [183]	validation_0-mlogloss:0.236018	validation_0-merror:0.072986
# [184]	validation_0-mlogloss:0.235261	validation_0-merror:0.072887
# [185]	validation_0-mlogloss:0.234568	validation_0-merror:0.072855
# [186]	validation_0-mlogloss:0.233885	validation_0-merror:0.072702
# [187]	validation_0-mlogloss:0.233191	validation_0-merror:0.072573
# [188]	validation_0-mlogloss:0.232551	validation_0-merror:0.072343
# [189]	validation_0-mlogloss:0.231819	validation_0-merror:0.072334
# [190]	validation_0-mlogloss:0.231061	validation_0-merror:0.072268
# [191]	validation_0-mlogloss:0.230376	validation_0-merror:0.072228
# [192]	validation_0-mlogloss:0.229691	validation_0-merror:0.072083
# [193]	validation_0-mlogloss:0.22893	validation_0-merror:0.072076
# [194]	validation_0-mlogloss:0.228294	validation_0-merror:0.071833
# [195]	validation_0-mlogloss:0.227707	validation_0-merror:0.071711
# [196]	validation_0-mlogloss:0.227068	validation_0-merror:0.071681
# [197]	validation_0-mlogloss:0.226456	validation_0-merror:0.071555
# [198]	validation_0-mlogloss:0.225868	validation_0-merror:0.071584
# [199]	validation_0-mlogloss:0.225306	validation_0-merror:0.07144
# [200]	validation_0-mlogloss:0.224726	validation_0-merror:0.071408
# [201]	validation_0-mlogloss:0.224111	validation_0-merror:0.071313
# [202]	validation_0-mlogloss:0.223463	validation_0-merror:0.071101
# [203]	validation_0-mlogloss:0.222898	validation_0-merror:0.071124
# [204]	validation_0-mlogloss:0.222304	validation_0-merror:0.071139
# [205]	validation_0-mlogloss:0.221745	validation_0-merror:0.070959
# [206]	validation_0-mlogloss:0.221175	validation_0-merror:0.070907
# [207]	validation_0-mlogloss:0.220572	validation_0-merror:0.070925
# [208]	validation_0-mlogloss:0.21998	validation_0-merror:0.070814
# [209]	validation_0-mlogloss:0.2194	validation_0-merror:0.070654
# [210]	validation_0-mlogloss:0.218879	validation_0-merror:0.07064
# [211]	validation_0-mlogloss:0.21827	validation_0-merror:0.070523
# [212]	validation_0-mlogloss:0.217737	validation_0-merror:0.070491
# [213]	validation_0-mlogloss:0.217197	validation_0-merror:0.07041
# [214]	validation_0-mlogloss:0.216667	validation_0-merror:0.070354
# [215]	validation_0-mlogloss:0.216197	validation_0-merror:0.070318
# [216]	validation_0-mlogloss:0.21568	validation_0-merror:0.070263
# [217]	validation_0-mlogloss:0.215173	validation_0-merror:0.070076
# [218]	validation_0-mlogloss:0.214639	validation_0-merror:0.070101
# [219]	validation_0-mlogloss:0.214166	validation_0-merror:0.070013
# [220]	validation_0-mlogloss:0.213628	validation_0-merror:0.06994
# [221]	validation_0-mlogloss:0.213108	validation_0-merror:0.06976
# [222]	validation_0-mlogloss:0.212639	validation_0-merror:0.069737
# [223]	validation_0-mlogloss:0.212183	validation_0-merror:0.069719
# [224]	validation_0-mlogloss:0.211717	validation_0-merror:0.069735
# [225]	validation_0-mlogloss:0.211196	validation_0-merror:0.069584
# [226]	validation_0-mlogloss:0.210686	validation_0-merror:0.069627
# [227]	validation_0-mlogloss:0.210226	validation_0-merror:0.069586
# [228]	validation_0-mlogloss:0.209752	validation_0-merror:0.069518
# [229]	validation_0-mlogloss:0.209326	validation_0-merror:0.069421
# [230]	validation_0-mlogloss:0.208917	validation_0-merror:0.069453
# [231]	validation_0-mlogloss:0.208496	validation_0-merror:0.069419
# [232]	validation_0-mlogloss:0.208065	validation_0-merror:0.069195
# [233]	validation_0-mlogloss:0.207644	validation_0-merror:0.06913
# [234]	validation_0-mlogloss:0.207249	validation_0-merror:0.069204
# [235]	validation_0-mlogloss:0.206859	validation_0-merror:0.069227
# [236]	validation_0-mlogloss:0.206472	validation_0-merror:0.069103
# [237]	validation_0-mlogloss:0.206027	validation_0-merror:0.069216
# [238]	validation_0-mlogloss:0.205633	validation_0-merror:0.069164
# [239]	validation_0-mlogloss:0.205181	validation_0-merror:0.069033
# [240]	validation_0-mlogloss:0.204767	validation_0-merror:0.068834
# [241]	validation_0-mlogloss:0.20438	validation_0-merror:0.068802
# [242]	validation_0-mlogloss:0.203981	validation_0-merror:0.068942
# [243]	validation_0-mlogloss:0.20354	validation_0-merror:0.068841
# [244]	validation_0-mlogloss:0.20317	validation_0-merror:0.068784
# [245]	validation_0-mlogloss:0.202798	validation_0-merror:0.06869
# [246]	validation_0-mlogloss:0.202393	validation_0-merror:0.068746
# [247]	validation_0-mlogloss:0.202013	validation_0-merror:0.06873
# [248]	validation_0-mlogloss:0.201617	validation_0-merror:0.068696
# [249]	validation_0-mlogloss:0.201242	validation_0-merror:0.068708
# [250]	validation_0-mlogloss:0.200877	validation_0-merror:0.068732
# [251]	validation_0-mlogloss:0.200472	validation_0-merror:0.068638
# [252]	validation_0-mlogloss:0.200136	validation_0-merror:0.068622
# [253]	validation_0-mlogloss:0.199787	validation_0-merror:0.068527
# [254]	validation_0-mlogloss:0.199432	validation_0-merror:0.06845
# [255]	validation_0-mlogloss:0.199082	validation_0-merror:0.068466
# [256]	validation_0-mlogloss:0.198727	validation_0-merror:0.068403
# [257]	validation_0-mlogloss:0.198366	validation_0-merror:0.068421
# [258]	validation_0-mlogloss:0.198033	validation_0-merror:0.068398
# [259]	validation_0-mlogloss:0.197661	validation_0-merror:0.068392
# [260]	validation_0-mlogloss:0.197311	validation_0-merror:0.068355
# [261]	validation_0-mlogloss:0.196987	validation_0-merror:0.068403
# [262]	validation_0-mlogloss:0.196628	validation_0-merror:0.068236
# [263]	validation_0-mlogloss:0.196313	validation_0-merror:0.068121
# [264]	validation_0-mlogloss:0.195973	validation_0-merror:0.068206
# [265]	validation_0-mlogloss:0.195683	validation_0-merror:0.068308
# [266]	validation_0-mlogloss:0.195433	validation_0-merror:0.068294
# [267]	validation_0-mlogloss:0.195105	validation_0-merror:0.068175
# [268]	validation_0-mlogloss:0.194745	validation_0-merror:0.068048
# [269]	validation_0-mlogloss:0.194464	validation_0-merror:0.0681
# [270]	validation_0-mlogloss:0.194163	validation_0-merror:0.068132
# [271]	validation_0-mlogloss:0.193822	validation_0-merror:0.068073
# [272]	validation_0-mlogloss:0.193519	validation_0-merror:0.068044
# [273]	validation_0-mlogloss:0.193233	validation_0-merror:0.067992
# [274]	validation_0-mlogloss:0.192937	validation_0-merror:0.067897
# [275]	validation_0-mlogloss:0.192645	validation_0-merror:0.067929
# [276]	validation_0-mlogloss:0.19236	validation_0-merror:0.06794
# [277]	validation_0-mlogloss:0.19204	validation_0-merror:0.067911
# [278]	validation_0-mlogloss:0.191753	validation_0-merror:0.067789
# [279]	validation_0-mlogloss:0.191464	validation_0-merror:0.067773
# [280]	validation_0-mlogloss:0.191172	validation_0-merror:0.067714
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.2, max_delta_step=0, max_depth=9,
#               min_child_weight=1, missing=None, n_estimators=281, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=1234,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=0.6, verbosity=1)

# %% [markdown]
# # 모델 검증

# %%
y_pred = bst.predict(X_test)
print('정확도 :', accuracy_score(y_test, y_pred.round()))
# Out:
# 정확도 : 0.9322858220194133

# %% [markdown]
# 모델 오류 참고자료
#
# https://github.com/dmlc/xgboost/issues/2073
#
# https://github.com/dmlc/xgboost/issues/3828

# %% [markdown]
# # 모델 시각화

# %%
# Print a confusion matrix
print('Confusion matrix:')
cm = confusion_matrix(y_test, y_pred)
cm = cm / cm.astype(np.float).sum(axis=1)
plt.rcParams['figure.figsize'] = [10,8]
sns.heatmap(cm, annot=True)
# Out:
# Confusion matrix:

# %%
# 방금시험했던 모델에서는 num_trees가 0~1799개 까지 있었다
xgb.to_graphviz(bst, num_trees=1)

# %%
xgb.plot_importance(bst)
plt.rcParams['figure.figsize'] = [10,8]

# %% [markdown]
# # 모델 튜닝

# %% [markdown]
# GridSearch 방법

# %%
bst_param_grid = {
    'learning_rate' : [0.2, 0.3, 0.4],
    'max_depth' : [2, 3, 4],
}

bst_grid = GridSearchCV(bst, param_grid= bst_param_grid, scoring='accuracy', n_jobs=-1, verbose=1)
bst_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.

# %%
bst_grid_df = pd.DataFrame(bst_grid.cv_results_)
bst_grid_df
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0      75.608240      0.832305  ...        0.001518                1
# 1      73.878399      1.876389  ...        0.002701                3
# 2      74.607954      1.205587  ...        0.001518                1
# 3      70.423602      1.615222  ...        0.002701                3
#
# [4 rows x 15 columns]

# %% [markdown]
# 베이지안 최적화 방법

# %%
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading https://files.pythonhosted.org/packages/bb/7a/fd8059a3881d3ab37ac8f72f56b73937a14e8bb14a9733e68cc8b17dbe3c/bayesian-optimization-1.2.0.tar.gz
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.18.5)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (0.17.0)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-cp36-none-any.whl size=11685 sha256=4e4842a50d20b40d8285ae43f9ff33f43e72a6dff484fc4be7ac924809d756f0
#   Stored in directory: /root/.cache/pip/wheels/5a/56/ae/e0e3c1fc1954dc3ec712e2df547235ed072b448094d8f94aec
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.2.0

# %% [markdown]
# https://www.kaggle.com/toastls93/bayes-optimization-xgb#XGB---learning_rate,-max_depth-%EB%93%B1-%EC%B5%9C%EC%A0%81%ED%99%94-%ED%95%98%EA%B8%B0

# %%
def XGB_cv(max_depth,learning_rate, n_estimators, gamma
           ,min_child_weight, max_delta_step, subsample
           ,colsample_bytree, silent=True, nthread=-1):
    model = xgb.XGBClassifier(max_depth=int(max_depth),
                              learning_rate=learning_rate,
                              n_estimators=int(n_estimators),
                              silent=silent,
                              nthread=nthread,
                              gamma=gamma,
                              min_child_weight=min_child_weight,
                              max_delta_step=max_delta_step,
                              subsample=subsample,
                              colsample_bytree=colsample_bytree)
    RMSE = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=4).mean()
    return -RMSE

pbounds = {'max_depth': (5, 10),
          'learning_rate': (0.01, 0.3),
          'n_estimators': (50, 1000),
          'gamma': (1., 0.01),
          'min_child_weight': (1, 10),
          'max_delta_step': (0, 0.1),
          'subsample': (0.6, 0.9),
          'colsample_bytree' :(0.5, 0.99)
          }

xgboostBO = BayesianOptimization(f = XGB_cv,pbounds = pbounds, verbose = 2, random_state = 1234 )

# 메소드를 이용해 최대화!
xgboostBO.maximize(init_points=2, n_iter = 10)

xgboostBO.max
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_de... | max_depth | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        | -0.5377   |  0.5938   |  0.3841   |  0.1369   |  0.07854  |  8.9      |  3.453    |  312.6    |  0.8406   |
# |  2        | -0.6369   |  0.9695   |  0.1328   |  0.1138   |  0.0501   |  8.417    |  7.414    |  401.7    |  0.7684   |
# |  3        | -0.1859   |  0.556    |  0.01     |  0.06995  |  0.04435  |  5.82     |  6.244    |  50.04    |  0.7004   |
# |  4        | -0.1801   |  0.5901   |  0.01     |  0.09931  |  0.008554 |  9.612    |  3.407    |  50.42    |  0.7209   |
# |  5        | -0.6598   |  0.6004   |  0.01     |  0.2578   |  0.03073  |  9.78     |  2.304    |  999.6    |  0.6251   |
# |  6        | -0.2064   |  0.5291   |  0.01     |  0.2395   |  0.03506  |  5.121    |  1.268    |  50.54    |  0.6383   |
# |  7        | -0.3714   |  0.5043   |  0.01     |  0.2082   |  0.01301  |  9.303    |  9.899    |  754.7    |  0.798    |
# |  8        | -0.4021   |  0.7961   |  0.01     |  0.09055  |  0.09319  |  9.894    |  9.543    |  136.0    |  0.692    |
# |  9        | -0.7522   |  0.8003   |  0.01     |  0.1339   |  0.06301  |  9.594    |  1.425    |  631.5    |  0.6575   |
# |  10       | -0.5834   |  0.5363   |  0.01     |  0.1142   |  0.07198  |  5.668    |  1.653    |  859.0    |  0.8238   |
# |  11       | -0.1758   |  0.8507   |  0.01     |  0.1448   |  0.03772  |  9.89     |  9.111    |  50.58    |  0.8034   |
# |  12       | -0.3554   |  0.9422   |  0.01     |  0.06244  |  0.04165  |  5.789    |  9.856    |  513.9    |  0.6728   |
# =========================================================================================================================
# {'params': {'colsample_bytree': 0.8506945992820225,
#   'gamma': 0.01,
#   'learning_rate': 0.1448396938292427,
#   'max_delta_step': 0.03771802050604797,
#   'max_depth': 9.890127006274056,
#   'min_child_weight': 9.110813179479896,
#   'n_estimators': 50.57849069226247,
#   'subsample': 0.8034242734858654},
#  'target': -0.17580640095480382}

# %%
fit_xgb = xgb.XGBClassifier(max_depth= int( xgboostBO.max['params']['max_depth'] ),
                             learning_rate=xgboostBO.max['params']['learning_rate'],
                             n_estimators=int(xgboostBO.max['params']['n_estimators']),
                             gamma= xgboostBO.max['params']['gamma'],
                             min_child_weight=xgboostBO.max['params']['min_child_weight'],
                             max_delta_step=xgboostBO.max['params']['max_delta_step'],
                             subsample=xgboostBO.max['params']['subsample'],
                             colsample_bytree=xgboostBO.max['params']['colsample_bytree'])

# %%
model  = fit_xgb.fit(X,y)

# %% [markdown]
# # 모델 저장
#
# 제대로 저장이 안되는 느낌
# colab 환경이라 그런가?

# %%
bst.save_model('/content/drive/My Drive/datasets/model.bst')

# %% [markdown]
# # 모델 저장및 불러오기 위해서 필요한 툴
#
# https://colab.research.google.com/github/pair-code/what-if-tool/blob/master/xgboost_caip_e2e.ipynb

# %%
import sys
python_version = sys.version_info[0]

# %%
# If you're running on Colab, you'll need to install the What-if Tool package and authenticate
# If you're on Cloud AI Platform Notebooks, you'll need to install XGBoost on the TF instance
def pip_install(module):
    if python_version == '2':
        # !pip install {module} --quiet
    else:
        # !pip3 install {module} --quiet

try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    pip_install('witwidget')

    from google.colab import auth
    auth.authenticate_user()
else:
    pip_install('xgboost')
# Out:
#      |████████████████████████████████| 2.3MB 2.7MB/s

# %%
import numpy as np
import collections
import witwidget

from sklearn.utils import shuffle
from witwidget.notebook.visualization import WitWidget, WitConfigBuilder

# %%
# Define some globals - update these to your own project + model names
GCP_PROJECT = 'YOUR_GCP_PROJECT'
MODEL_BUCKET = 'gs://your_storage_bucket'
MODEL_NAME = 'case1' # You'll create this model below
VERSION_NAME = 'v1'

# %%
# Copy your model file to Cloud Storage
# !gsutil cp ./model.bst $MODEL_BUCKET
# Out:
# Copying file://./model.bst [Content-Type=application/octet-stream]...
# NotFoundException: 404 The destination bucket gs://your_storage_bucket does not exist or the write to the destination must be restarted

# %%
# Configure gcloud to use your project
# !gcloud config set project $GCP_PROJECT

# %%
# Create a model
# !gcloud ai-platform models create $MODEL_NAME

# %%
# Create a version, this will take ~2 minutes to deploy
# !gcloud ai-platform versions create $VERSION_NAME \
--model=$MODEL_NAME \
--framework='XGBOOST' \
--runtime-version=1.14 \
--origin=$MODEL_BUCKET \
--python-version=3.5 \
--project=$GCP_PROJECT

# %%
# Format a subset of the test data to send to the What-if Tool for visualization
# Append ground truth label value to training data

# This is the number of examples you want to display in the What-if Tool
num_wit_examples = 500
test_examples = np.hstack((X_test[:num_wit_examples].values,y_test[:num_wit_examples].reshape(-1,1)))

# %%
# Create a What-if Tool visualization, it may take a minute to load
# See the cell below this for exploration ideas

# This prediction adjustment function is needed as this xgboost model's
# prediction returns just a score for the positive class of the binary
# classification, whereas the What-If Tool expects a list of scores for each
# class (in this case, both the negative class and the positive class).
def adjust_prediction(pred):
  return [1 - pred, pred]

config_builder = (WitConfigBuilder(test_examples.tolist(), data.columns.tolist() + ['mortgage_status'])
  .set_ai_platform_model(GCP_PROJECT, MODEL_NAME, VERSION_NAME, adjust_prediction=adjust_prediction)
  .set_target_feature('mortgage_status')
  .set_label_vocab(['denied', 'approved']))
WitWidget(config_builder, height=800)

# %% [markdown]
# # 모델 로드

# %%
xgbc = xgb.XGBClassifier(random_state=1234)
xgbc.load_model('/content/drive/My Drive/datasets/model.bst')
